# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/wine-reviews/winemag-data-130k-v2.json
# /kaggle/input/wine-reviews/winemag-data_first150k.csv
# /kaggle/input/wine-reviews/winemag-data-130k-v2.csv
# /kaggle/input/fruits-with-colors-dataset/fruit_data_with_colors.txt

# %%
# !ls  /kaggle/input/wine-reviews
# Out:
# winemag-data-130k-v2.csv  winemag-data-130k-v2.json  winemag-data_first150k.csv

# %%
data = pd.read_csv('/kaggle/input/wine-reviews/winemag-data_first150k.csv')

# %%
data.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
data['country'].head()
# Out:
# 0        US
# 1     Spain
# 2        US
# 3        US
# 4    France
# Name: country, dtype: object

# %%
data['province'][14]
# Out:
# 'Oregon'

# %%
data.rename(columns={"Unnamed: 0": "testing_id"})
# Out:
#         testing_id country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %%
data_new = data.rename(columns={"Unnamed: 0": "testing_id"})

# %%
data_new.head()
# Out:
#    testing_id country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
data = data.rename(columns={"Unnamed: 0": "testing_id"})

# %%
data[data['country'].isin(['US'])]['price'].max()
# Out:
# 2013.0

# %%
data.loc[data[data['country'].isin(['US'])]['price'].idxmax()]
# Out:
# testing_id                                                 13318
# country                                                       US
# description    The nose on this single-vineyard wine from a s...
# designation                                  Roger Rose Vineyard
# points                                                        91
# price                                                       2013
# province                                              California
# region_1                                             Arroyo Seco
# region_2                                           Central Coast
# variety                                               Chardonnay
# winery                                                     Blair
# Name: 13318, dtype: object

# %%
data.groupby(['country','variety'])['price'].sum().head(10)
# Out:
# country    variety
# Albania    Kallmet                                 40.0
# Argentina  Barbera                                 36.0
#            Bonarda                               2269.0
#            Bordeaux-style Red Blend              4629.0
#            Bordeaux-style White Blend              42.0
#            Cabernet Blend                         235.0
#            Cabernet Franc                         663.0
#            Cabernet Sauvignon                   13757.0
#            Cabernet Sauvignon-Cabernet Franc       36.0
#            Cabernet Sauvignon-Malbec             1657.0
# Name: price, dtype: float64

# %%
data.groupby(['country','variety'])['price'].sum().reset_index(name='max_price_per_coutry_variety').head(10)
# Out:
#      country                            variety  max_price_per_coutry_variety
# 0    Albania                            Kallmet                          40.0
# 1  Argentina                            Barbera                          36.0
# 2  Argentina                            Bonarda                        2269.0
# 3  Argentina           Bordeaux-style Red Blend                        4629.0
# 4  Argentina         Bordeaux-style White Blend                          42.0
# 5  Argentina                     Cabernet Blend                         235.0
# 6  Argentina                     Cabernet Franc                         663.0
# 7  Argentina                 Cabernet Sauvignon                       13757.0
# 8  Argentina  Cabernet Sauvignon-Cabernet Franc                          36.0
# 9  Argentina          Cabernet Sauvignon-Malbec                        1657.0

# %%
data.drop_duplicates('variety').tail(20)['variety']
# Out:
#         testing_id    country  \
# 106463      106463    Hungary
# 106694      106694         US
# 106972      106972      Italy
# 107744      107744      Spain
# 108089      108089     Canada
# 112066      112066     France
# 114160      114160         US
# 115928      115928     France
# 126119      126119         US
# 127230      127230         US
# 131608      131608   Portugal
# 134851      134851   Portugal
# 138961      138961         US
# 143796      143796     France
# 144004      144004      Spain
# 146181      146181    Germany
# 146801      146801     France
# 147637      147637      Italy
# 147654      147654      Spain
# 149108      149108  Australia
#
#                                               description  \
# 106463  Intense notes of white flower and lemon peel p...
# 106694  Big aromas of pineapple, citrus and flowers le...
# 106972  Made from Vermentino Nero, this unique red rec...
# 107744  This is made from an obscure grape called Pard...
# ...

# %%
# %%html
# <iframe src="https://seaborn.pydata.org/" width="600" height="500"></iframe>
# Out:
# <iframe src="https://seaborn.pydata.org/" width="1200" height="1000"></iframe>

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(y="country",data=data.sort_values(by=['price'],ascending=False).head(100))
plt.show()

# %%
sns.countplot(y="country",hue = "variety", data=data.sort_values(by=['price'],ascending=False).head(10))
plt.show()

# %%
data_subset = data[data['country'].isin(['US','France','Italy'])].sort_values(by=['points'],ascending=False)

# %%
data_subset.head()
# Out:
#         testing_id country                                        description  \
# 114272      114272      US  Impossibly aromatic. Hard to imagine greater c...
# 137099      137099      US  Tasted in a flight of great and famous Napa wi...
# 41521        41521   Italy  A perfect wine from a classic vintage, the 200...
# 83536        83536  France  A wine that has created its own universe. It h...
# 28954        28954   Italy  This small, family-run estate in the heart of ...
#
#              designation  points   price    province            region_1  \
# 114272          Red Wine     100   245.0  California          Rutherford
# 137099               NaN     100   200.0  California         Napa Valley
# 41521            Masseto     100   460.0     Tuscany             Toscana
# 83536     Clos du Mesnil     100  1400.0   Champagne           Champagne
# 28954   Guado de' Gemoli     100   195.0     Tuscany  Bolgheri Superiore
#
# ...

# %%
sns.catplot(x="country", y="points", kind="box", data=data_subset);

# %%
sns.catplot(x="country", y="price", data=data_subset);

# %%
sns.distplot(data_subset['price'].fillna(0).astype(int));

# %%
# %load_ext sympyprinting
import sympy as sym
from sympy import *
# Out:
# The sympyprinting extension is already loaded. To reload it, use:
#   %reload_ext sympyprinting

# %%
x, y, z = sym.symbols("x y z")
Rational(3,2)*pi + exp(I*x) / (x**2 + y)
# Out:
# 3*pi/2 + exp(I*x)/(x**2 + y)

# %%
eq = ((x+y)**2 * (x+1))
eq
# Out:
# (x + 1)*(x + y)**2

# %%
expand(eq)
# Out:
# x**3 + 2*x**2*y + x**2 + x*y**2 + 2*x*y + y**2

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('Wjboy91Ofuc')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/Wjboy91Ofuc"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
